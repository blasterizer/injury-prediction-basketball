# %%
# import pandas as pd
# from google.colab import files

# # Upload the dataset file from your local system
# uploaded = files.upload()

# # Assuming the file name is 'all_seasons.csv', change this if your file has a different name
# file_name = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-6843ddeb-b0b5-40e4-accd-c1c6471c6043" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6843ddeb-b0b5-40e4-accd-c1c6471c6043">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Mounting File from drive directly

# %%
#mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
# Read the dataset
df = pd.read_csv('/content/drive/MyDrive/Practicum/all_seasons.csv')

# Selecting the required columns
selected_columns = ['player_name', 'team_abbreviation', 'age', 'player_height', 'player_weight', 'season']
df_selected = df[selected_columns]

# Filtering the dataset for the specified seasons
seasons_required = [f"{year}-{str(year+1)[2:]}" for year in range(2010, 2020)]
df_filtered = df_selected[df_selected['season'].isin(seasons_required)]

# Save the cleaned dataset to a new file
output_file = 'cleaned_all_seasons_dataset.csv'
df_filtered.to_csv(output_file, index=False)

# Download the cleaned file
##files.download(output_file)

# %%
df_filtered.tail()
# Out:
#            player_name team_abbreviation   age  player_height  player_weight  \
# 11155   Nikola Vucevic               ORL  29.0         210.82     117.933920
# 11156      Noah Vonleh               DEN  24.0         208.28     116.573144
# 11157     Norvel Pelle               PHI  27.0         208.28     104.779752
# 11158  Nicolas Claxton               BKN  21.0         210.82      97.522280
# 11159    Norman Powell               TOR  27.0         190.50      97.522280
#
#         season
# 11155  2019-20
# 11156  2019-20
# 11157  2019-20
# 11158  2019-20
# 11159  2019-20

# %%
injuries_df = pd.read_excel('/content/drive/MyDrive/Practicum/injuries_2010-2020Final_070121_v3.xlsx')
injuries_df.tail()

# %%
injuries_df.columns
# Out:
# Index(['Date', 'Duplicates', 'PLAYER_ID', 'Player', 'Season', 'TEAM_ID',
#        'TEAM_Abbr', 'TEAM_CITY', 'Health problems', 'Organ systems',
#        'Major anatomical areas', 'Anatomical sub-areas', 'Decision', 'Notes'],
#       dtype='object')

# %%
injuries_df[injuries_df['Duplicates']=='D']

# %%
cleaned_df = pd.read_csv('/content/drive/MyDrive/Practicum/cleaned_data.csv')
cleaned_df.head()

# %%
columns_select=['Player','Ht','Wt','Pos','Age','Tm','G','GS','MP','FGA','ORB','DRB','TRB','Year','Team']
clean_select=cleaned_df[columns_select]
clean_select.head()

# %%
clean_select.Year.dtype
# Out:
# dtype('float64')

# %%
#Need to change the year to the respective season, by investigating it was found 2018 year is same as 2017-18 season and so on
#Function for that
def convert_year_season(year):
  year_str = str(int(year))
  start = str(int(year)-1)
  return start + '-' + year_str[-2:]
print(convert_year_season(1991.0))
# Out:
# 1990-91

# %%
#Applying it over the entire column of the df
clean_select['Year']=clean_select['Year'].apply(convert_year_season)
clean_select.head()

# %%
clean_select.tail()
# Out:
#                   Player    Ht     Wt Pos  Age   Tm   G  GS    MP   FGA  ORB  \
# 17971  DeShawn Stevenson   6-5  210.0  SG   31  ATL  56  31  20.7   4.7  0.3
# 17972        Jeff Teague   6-3  195.0  PG   24  ATL  80  78  32.9  12.2  0.3
# 17973   Anthony Tolliver   6-8  240.0  SF   27  ATL  62  11  15.5   3.5  0.5
# 17974       Jeremy Tyler  6-10  260.0   C   21  ATL  21   0   3.2   1.1  0.3
# 17975       Lou Williams   6-1  175.0  SG   26  ATL  39   9  28.7  11.4  0.2
#
#        DRB  TRB     Year           Team
# 17971  1.9  2.2  2012-13  Atlanta Hawks
# 17972  1.9  2.3  2012-13  Atlanta Hawks
# 17973  2.0  2.5  2012-13  Atlanta Hawks
# 17974  0.7  1.0  2012-13  Atlanta Hawks
# 17975  1.8  2.1  2012-13  Atlanta Hawks

# %%
clean_select.Year.dtype
# Out:
# dtype('O')

# %%
seasons_required = [f"{Year}-{str(Year+1)[2:]}" for Year in range(2010, 2020)]
clean_stats = clean_select[clean_select['Year'].isin(seasons_required)]
clean_stats

# %%
df_filtered
# Out:
#            player_name team_abbreviation   age  player_height  player_weight  \
# 6226          JR Smith               DEN  25.0         198.12      99.790240
# 6227      JaVale McGee               WAS  23.0         213.36     114.305184
# 6228   Jamaal Magloire               MIA  33.0         210.82     115.665960
# 6229       James Posey               IND  34.0         203.20      98.429464
# 6230      Jamario Moon               LAC  31.0         203.20      92.986360
# ...                ...               ...   ...            ...            ...
# 11155   Nikola Vucevic               ORL  29.0         210.82     117.933920
# 11156      Noah Vonleh               DEN  24.0         208.28     116.573144
# 11157     Norvel Pelle               PHI  27.0         208.28     104.779752
# 11158  Nicolas Claxton               BKN  21.0         210.82      97.522280
# 11159    Norman Powell               TOR  27.0         190.50      97.522280
#
#         season
# 6226   2010-11
# ...

# %%
#Looks like there are some more players in clean_stats df

# %%
clean_stats=clean_stats.sort_values('Year')
clean_stats

# %%
players_1 = set(clean_stats['Player'])
players_2 = set(df_filtered['player_name'])
players_3 = set(injuries_df.Player)
players_unique_1 = players_1 - players_2
players_unique_2 = players_2 - players_1
players_unique_3 = players_3 - players_2
(players_unique_2)

# %%
injuries_df.loc[injuries_df['Player']=='Yakuba Ouattara']

# %% [markdown]
# Need to sort out the the different name formats, like J.R. Smith is same as JR Smith and so on

# %%
#df_filtered['player_name'] = df_filtered['player_name'].str.replace(r"([A-Z]{1})([A-Z]{1})", r"\1.\2", regex=True)

# %% [markdown]
# Just take a look at this function maybe it will make the name standardize

# %%
# Function to standardize name formats
# def standardize_name(name):
#     name = name.replace(".", "")
#     name = " ".join(name.split())
#     return name.upper()  # Convert to uppercase for consistency

# df_filtered['standardized_player_name'] = df_filtered['player_name'].apply(standardize_name)

# print(df_filtered[['player_name', 'standardized_player_name']].head())

# %% [markdown]
# This converts the dot to joint words but in the injuries dataset we have the names with the dots. So just need the opposite of this

# %%
#Some team names need cleaning too: New Jersey nets and Brooklyn Nets are same
teams_1 = set(df_filtered.team_abbreviation)
teams_2 = set(clean_stats.Tm)
teams_1-teams_2
# Out:
# {'BKN', 'PHX'}

# %%
clean_stats.loc[clean_stats['Player']=='CJ McCollum']

# %%
import re
pattern = r'\b[A-Z]\.[A-Z]\. [A-Z][a-z]+\b'
matching_players_injuries = set()
matching_players_clean_stats = set()

# Iterate through the DataFrame and filter out the names that match the pattern
for name in injuries_df['Player']:
    if re.search(pattern, name):
        matching_players_injuries.add(name)

for name in clean_stats['Player']:
    if re.search(pattern, name):
        matching_players_clean_stats.add(name)

matching_players_clean_stats, matching_players_injuries

# %%
pattern_2 = r'\b[A-Z]{2} [A-Z][a-z]+\b'

matching_players_df_filtered = set()
matching_players_injuries = set()
for name in df_filtered['player_name']:
    if re.search(pattern_2, name):
        matching_players_df_filtered.add(name)

for name in injuries_df['Player']:
    if re.search(pattern_2, name):
        matching_players_injuries.add(name)

matching_players_df_filtered, matching_players_injuries
#len(matching_players_df_filtered), len(matching_players_clean_stats)

# %%
#So only two players in the injuries database we need to be careful about  {'OG Anunoby', 'RJ Barrett'}
# Apparently these two names are in the same format in all the three dataframes
# Step 1: Convert the required names

# %%
# names_1={'AJ Hammons','AJ Price','BJ Johnson','CJ Miles',  'CJ Wilcox',  'DJ Mbenga',  'DJ Stephens',  'DJ White',  'JJ Hickson',  'JJ Redick',  'JR Smith',
# KZ Okpala',  'OG Anunoby',  'PJ Dozier',  'PJ Hairston',  'PJ Tucker',  'RJ Barrett',  'RJ Hunter',  'TJ Leaf',  'TJ Warren'}

#names_2= {'A.J. Hammons','A.J. Price','B.J. Johnson','C.J. Miles','C.J. Watson','C.J. Wilcox','C.J. Williams','D.J. Augustin','D.J. Kennedy','D.J. Mbenga',
#  'D.J. Stephens','D.J. White','D.J. Wilson','J.J. Barea','J.J. Hickson','J.J. Redick','J.P. Macura','J.R. Smith','O.J. Mayo','P.J. Hairston','P.J. Tucker',
#  'P.J. Washington','R.J. Hunter','T.J. Ford','T.J. Leaf','T.J. Warren'}

#names_3_injuries = {'A.J. Price',  'C.J. Miles','C.J. Watson','C.J. Wilcox','C.J. Williams','D.J. Augustin','D.J. White','D.J. Wilson','J.J. Barea',
#  'J.J. Hickson','J.J. Redick','J.R. Smith','O.J. Mayo','P.J. Hairston','P.J. Tucker','P.J. Washington','R.J. Hunter','T.J. Ford',
#  'T.J. Leaf','T.J. Warren'})

#for names_1 and names_2 noticed 'KZ Okpala' and 'PJ Dozier' are in the same format too so the list becomes {'OG Anunoby','RJ Barrett','KZ Okpala','PJ Dozier'}
# Some names are in proper format that's why can't use regular expression

# %%
# names of the players needed to be converted
conversion_dict = {
    'AJ Hammons': 'A.J. Hammons',
    'AJ Price': 'A.J. Price',
    'BJ Johnson': 'B.J. Johnson',
    'CJ Miles': 'C.J. Miles',
    'CJ Wilcox': 'C.J. Wilcox',
    'DJ Mbenga': 'D.J. Mbenga',
    'DJ Stephens': 'D.J. Stephens',
    'DJ White': 'D.J. White',
    'JJ Hickson': 'J.J. Hickson',
    'JJ Redick': 'J.J. Redick',
    'JR Smith': 'J.R. Smith',
    'KJ McDaniels': 'K.J. McDaniels',
    'PJ Hairston': 'P.J. Hairston',
    'PJ Tucker': 'P.J. Tucker',
    'RJ Hunter': 'R.J. Hunter',
    'TJ Leaf': 'T.J. Leaf',
    'TJ Warren': 'T.J. Warren'
}

def convert_name(name):
    if name in conversion_dict:
        return conversion_dict[name]
    else:
        return name
df_filtered['player_name'] = df_filtered['player_name'].apply(convert_name)
# Out:
# <ipython-input-24-c32f164fb4bc>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['player_name'] = df_filtered['player_name'].apply(convert_name)

# %% [markdown]
# The first format of names are cleaned, now to worry about the turkish and other european names as well as Roman numerals and Jr

# %%
players_1 = set(clean_stats['Player'])
players_2 = set(df_filtered['player_name'])
players_3 = set(injuries_df.Player)
players_unique_1 = players_1 - players_2
players_unique_2 = players_2 - players_1
players_unique_3 = players_3 - players_2
players_unique_4 = players_3 - players_1
(players_unique_1),(players_unique_2),(players_unique_3),(players_unique_4)

# %%
df_filtered.loc[df_filtered['player_name']=='Eugene Jeter']
#clean_stats.loc[clean_stats['Player']=='Eugene Jeter']
# Out:
# Empty DataFrame
# Columns: [player_name, team_abbreviation, age, player_height, player_weight, season]
# Index: []

# %%
#something was wrong with the regular expression as it could not match McDaniels so had to figure that out

# clean_stats.loc[clean_stats['Player']=='K.J. McDaniels']
df_filtered.loc[df_filtered['player_name']=='K.J. McDaniels']
#injuries_df.loc[injuries_df['Player']=='K.J. McDaniels']
# Out:
#          player_name team_abbreviation   age  player_height  player_weight  \
# 8507  K.J. McDaniels               HOU  22.0         198.12       92.98636
# 9002  K.J. McDaniels               HOU  23.0         198.12       92.98636
# 9162  K.J. McDaniels               BKN  24.0         198.12       92.98636
#
#        season
# 8507  2014-15
# 9002  2015-16
# 9162  2016-17

# %%
#Modifying the team names
teams_1 = set(df_filtered.team_abbreviation)
teams_2 = set(clean_stats.Tm)
teams_3 = set(injuries_df.TEAM_Abbr)
print(len(teams_1), len(teams_2), len(teams_3)) #was previously 32,33,32 as explained later
print(teams_2-teams_1)
print(teams_1-teams_2)
print(teams_1-teams_3)
print(teams_3-teams_2)
# teams_1

# %% [markdown]
# **BRK** and **BKN** are same **Brooklyn Nets** and **PHO** and **PHX** are same **Phoenix Suns**, but need to worry about the other teams

# %%
#Looks like some team name is duplicated, need to study, as per the current standings only 30 teams are there
team_name_2 = set(clean_stats.Team)
(team_name_2)

# %%
clean_stats.loc[clean_stats['Tm']=='NOH']

# %% [markdown]
# After observation it is found **New Jersey Nets and Brooklyn Nets** are same; **Charlotte Bobcats and Charlotte Hornets** are same; **New Orleans Hornets and New Orleans Pelicans** are same. So we have to manipulate the data in that way

# %%
#Since injuries and df_filtered have same team names and numbers will convert it to that,
#but before that will need to convert the team Charlotte Bobcats of clean_stats as it isnt there in either of the two
clean_stats.loc[clean_stats['Tm']=='CHA'].head(), clean_stats.loc[clean_stats['Tm']=='CHO'].head()

#Note that in clean_stats CHA is Bobcats but CHO is Hornets, but in the rest CHA is Hornets, so need to be careful

# %%
clean_stats.loc[clean_stats['Tm'] == 'CHO', 'Tm'] = 'CHA'
clean_stats.loc[clean_stats['Team'] == 'Charlotte Bobcats', 'Team'] = 'Charlotte Hornets'

# %%
clean_stats.loc[clean_stats['Tm']=='CHA'].head()

# %%
print(len(teams_1), len(teams_2), len(teams_3))
# Out:
# 32 33 32

# %%
clean_stats.loc[clean_stats['Tm']=='PHO'].head()

# %%
clean_stats.loc[clean_stats['Tm'] == 'PHO', 'Tm'] = 'PHX'
clean_stats.loc[clean_stats['Tm'] == 'BRK', 'Tm'] = 'BKN'

# %%
teams_1 = set(df_filtered.team_abbreviation)
teams_2 = set(clean_stats.Tm)
teams_3 = set(injuries_df.TEAM_Abbr)
print(len(teams_1), len(teams_2), len(teams_3)) #was previously 32,33,32 as explained later
print(teams_2-teams_1)
print(teams_1-teams_2)
print(teams_1-teams_3)
print(teams_3-teams_2)

# %%
#After observation it is found New Jersey Nets and Brooklyn Nets are same;
#New Orleans Hornets and New Orleans Pelicans are same in all three dataframes

clean_stats.loc[clean_stats['Tm']=='NOH'].head(8)

# %% [markdown]
# ###new thing to clean two Patrick Ewings why???

# %%
clean_stats.loc[clean_stats['Tm'] == 'NOH', 'Tm'] = 'NOP'
clean_stats.loc[clean_stats['Team'] == 'New Orleans Hornets', 'Team'] = 'New Orleans Pelicans'

# %%
clean_stats.loc[clean_stats['Tm']=='NOH'].head(8)
# injuries_df.loc[injuries_df['TEAM_Abbr']=='BKN'].head(8)

# %%
clean_stats.loc[clean_stats['Tm']=='BKN'].head(8)

# %%
clean_stats.loc[clean_stats['Tm'] == 'NJN', 'Tm'] = 'BKN'
clean_stats.loc[clean_stats['Team'] == 'New Jersey Nets', 'Team'] = 'Brooklyn Nets'

# %%
team_name_2 = set(clean_stats.Team)
len(team_name_2)
# Out:
# 30

# %%
# Similarly for the other two dataframes
injuries_df.columns, df_filtered.columns

# %%
#First injuries dataframe
injuries_df.loc[injuries_df['TEAM_Abbr'] == 'NOH', 'TEAM_Abbr'] = 'NOP'
injuries_df.loc[injuries_df['TEAM_Abbr'] == 'NJN', 'TEAM_Abbr'] = 'BKN'

#Now the df_filtered
df_filtered.loc[df_filtered['team_abbreviation'] == 'NOH', 'team_abbreviation'] = 'NOP'
df_filtered.loc[df_filtered['team_abbreviation'] == 'NJN', 'team_abbreviation'] = 'BKN'

# %%
teams_1 = set(df_filtered.team_abbreviation)
teams_2 = set(clean_stats.Tm)
teams_3 = set(injuries_df.TEAM_Abbr)
print(len(teams_1), len(teams_2), len(teams_3)) #was previously 32,33,32 as explained later
print(teams_2-teams_1)
print(teams_1-teams_2)
print(teams_1-teams_3)
print(teams_3-teams_2)
# Out:
# 30 30 30
# set()
# set()
# set()
# set()

# %% [markdown]
# Team names cleaning complete !

# %%
#Random subspace of features for Random Forest seems applicable in this case, like this, subset of features(height weight games->1 ; height games rebounds -> 2)
#Also need to figure out if we want to use BMI or height and weight for modelling

# %% [markdown]
# new thing to clean two Patrick Ewings why???

# %%
duplicates_count = clean_stats.duplicated(subset=["Player", "Year", "Team"]).sum()
print("Total number of duplicates:", duplicates_count)
# Out:
# Total number of duplicates: 42

# %%
duplicates = clean_stats[clean_stats.duplicated(subset=["Player", "Year", "Team"], keep=False)]
duplicates
# Out:
#                 Player    Ht     Wt Pos  Age   Tm   G  GS    MP  FGA  ORB  \
# 1544   Reggie Williams   6-7  190.0  SF   24  GSW  80   9  20.3  7.2  0.6
# 1545   Reggie Williams   6-6  205.0  SF   24  GSW  80   9  20.3  7.2  0.6
# 3844     Chris Johnson  6-11  210.0   C   25  BOS  14   1   9.9  1.5  0.9
# 3845     Chris Johnson   6-6  206.0   C   25  BOS  14   1   9.9  1.5  0.9
# 4762     Patrick Ewing   7-0  240.0  SF   26  NOP   7   0   2.7  0.7  0.1
# ...                ...   ...    ...  ..  ...  ...  ..  ..   ...  ...  ...
# 2347   Reggie Williams   6-6  205.0  SF   30  NOP   6   0  13.2  3.8  0.3
# 5295  Gerald Henderson   6-2  175.0  SG   29  PHI  72  41  23.2  7.7  0.5
# 5296  Gerald Henderson   6-5  215.0  SG   29  PHI  72  41  23.2  7.7  0.5
# 4039        Mike James   6-1  189.0  PG   27  NOP  36  10  19.1  8.9  0.4
# 4038        Mike James   6-2  188.0  PG   27  NOP  36  10  19.1  8.9  0.4
#
#       DRB  TRB     Year                   Team
# ...

# %%
df_filtered.loc[df_filtered['player_name']=='Reggie Williams']
# Out:
#           player_name team_abbreviation   age  player_height  player_weight  \
# 6617  Reggie Williams               GSW  24.0          201.0           86.0
# 7131  Reggie Williams               CHA  25.0          201.0           86.0
# 7218  Reggie Williams               CHA  26.0          201.0           86.0
# 7900  Reggie Williams               OKC  27.0          201.0           86.0
# 8157  Reggie Williams               SAS  28.0          201.0           86.0
# 9263  Reggie Williams               NOP  30.0          201.0           86.0
#
#        season
# 6617  2010-11
# 7131  2011-12
# 7218  2012-13
# 7900  2013-14
# 8157  2014-15
# 9263  2016-17

# %% [markdown]
# Looks like there are some discrepancies in the heights and weights, maybe they just grew over the course of the season, but for consistency we will take the physical stats from the df_filtered dataframe

# %%
duplicates = df_filtered[df_filtered.duplicated(subset=["player_name", "season", "team_abbreviation"], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [player_name, team_abbreviation, age, player_height, player_weight, season]
# Index: []

# %%
clean_stats = clean_stats.drop_duplicates(subset=["Player", "Year", "Team"])
clean_stats
# Out:
#                  Player    Ht     Wt Pos  Age   Tm   G  GS    MP   FGA  ORB  \
# 2262      José Calderón   6-3  200.0  PG   29  TOR  68  55  30.9   8.8  0.4
# 6798     Mario Chalmers   6-2  190.0  PG   24  MIA  70  28  22.6   5.5  0.2
# 6797         Chris Bosh  6-11  235.0  PF   26  MIA  77  77  36.3  13.7  1.8
# 6796         Mike Bibby   6-1  190.0  PG   32  MIA  80  68  28.6   7.2  0.2
# 6795       Joel Anthony   6-9  245.0   C   28  MIA  75  11  19.5   1.3  1.4
# ...                 ...   ...    ...  ..  ...  ...  ..  ..   ...   ...  ...
# 3162      Jahlil Okafor  6-10  270.0   C   24  NOP  30   9  15.6   5.4  1.6
# 3161      E'Twaun Moore   6-3  191.0  SG   30  NOP  56   6  18.2   7.8  0.6
# 3160       Nicolò Melli   6-9  236.0   C   29  NOP  60   8  17.4   5.4  0.6
# 11747  D'Angelo Russell   6-4  193.0  PG   23  MIN  45  45  32.3  18.8  0.4
# 7120    Otto Porter Jr.   6-8  198.0  SF   26  CHI  14   9  23.6  10.0  0.9
#
#        DRB  TRB     Year                    Team
# ...

# %%
duplicates = clean_stats[clean_stats.duplicated(subset=["Player", "Year", "Team"], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [Player, Ht, Wt, Pos, Age, Tm, G, GS, MP, FGA, ORB, DRB, TRB, Year, Team]
# Index: []

# %%
conversion_names = {
  'Alen Smailagić':'Alen Smailagic',
  'Álex Abrines':'Alex Abrines',
  'Alexis Ajinça':'Alexis Ajinca',
  'Anderson Varejão':	  'Anderson Varejao',
  'Andrew White':	  'Andrew White III',
  'Andris Biedriņš':	  'Andris Biedrins',
  'Andrés Nocioni':	  'Andres Nocioni',
  'Ángel Delgado':	  'Angel Delgado',
  'Ante Žižić':	  'Ante Zizic',
  'Anžejs Pasečņiks':	  'Anzejs Pasecniks',
  'Boban Marjanović':	  'Boban Marjanovic',
  'Bogdan Bogdanović':	  'Bogdan Bogdanovic',
  'Bojan Bogdanović':	  'Bojan Bogdanovic',
  'Brian Bowen':	  'Brian Bowen II',
  'Cristiano Felício':	  'Cristiano Felicio',
  'Dairis Bertāns':	  'Dairis Bertans',
  #'Danuel House Jr.':	  'Danuel House',
  'Danuel House' : 'Danuel House Jr.',
  'Damjan Rudež':	  'Damjan Rudez',
  'Dario Šarić':	  'Dario Saric',
  'Darko Miličić':	  'Darko Milicic',
  'Dennis Schröder':	  'Dennis Schroder',
  'Derrick Walton':	  'Derrick Walton Jr.',
  'Donatas Motiejūnas':	  'Donatas Motiejunas',
  'Donté Greene':	  'Donte Greene',
  'Dāvis Bertāns':	  'Davis Bertans',
  'Džanan Musa':	  'Dzanan Musa',
  'Eduardo Nájera':	  'Eduardo Najera',
  'Enes Freedom':	  'Enes Kanter',
  'Ersan İlyasova':	  'Ersan Ilyasova',
  'Eugene Jeter':	  'Pooh Jeter',
  'Francisco García':	  'Francisco Garcia',
  'Frank Mason III':	  'Frank Mason',
  'Glen Rice Jr.':	  'Glen Rice',
  'Goran Dragić':	  'Goran Dragic',
  'Greivis Vásquez':	  'Greivis Vasquez',
  'Gustavo Ayón':	  'Gustavo Ayon',
  "Hamady N'Diaye":	  'Hamady Ndiaye',
  'Harry Giles':	  'Harry Giles III',
  'Hedo Türkoğlu':	  'Hedo Turkoglu',
  "J.J. O'Brien":	  "JJ O'Brien",
  'Jan Veselý':	  'Jan Vesely',
  'Jeff Taylor':	  'Jeffery Taylor',
  "Johnny O'Bryant":	  "Johnny O'Bryant III",
  'Jonas Valančiūnas':	  'Jonas Valanciunas',
  'Jorge Gutiérrez':	  'Jorge Gutierrez',
  'José Calderón':	  'Jose Calderon',
  'Juancho Hernangómez':	  'Juancho Hernangomez',
  'Jusuf Nurkić':	  'Jusuf Nurkic',
  'Kevin Knox':	  'Kevin Knox II',
  'Kevin Séraphin':	  'Kevin Seraphin',
  'Kristaps Porziņģis':	  'Kristaps Porzingis',
  'Luka Dončić':	  'Luka Doncic',
  'Luka Šamanić':	  'Luka Samanic',
  'Marcus Morris': 'Marcus Morris Sr.',
  'Manu Ginóbili':	  'Manu Ginobili',
  'Matt Williams':	  'Matt Williams Jr.',
  'Melvin Frazier':	  'Melvin Frazier Jr.',
  'Michael Frazier':	  'Michael Frazier II',
  'Mickaël Gelabale':	  'Mickael Gelabale',
  'Mickaël Piétrus':	  'Mickael Pietrus',
  'Miloš Teodosić':	  'Milos Teodosic',
  'Mirza Teletović':	  'Mirza Teletovic',
  'Mitch Creek':	  'Mitchell Creek',
  'Nemanja Nedović':	  'Nemanja Nedovic',
  'Nenad Krstić':	  'Nenad Krstic',
  'Nenê':	  'Nene',
  'Nicolás Brussino':	  'Nicolas Brussino',
  'Nic Claxton':	  'Nicolas Claxton',
  'Nicolás Laprovíttola':	  'Nicolas Laprovittola',
  'Nicolò Melli':	  'Nicolo Melli',
  'Nikola Jokić':	  'Nikola Jokic',
  'Nikola Mirotić':	  'Nikola Mirotic',
  'Nikola Peković':	  'Nikola Pekovic',
  'Nikola Vučević':	  'Nikola Vucevic',
  'Ognjen Kuzmić':	  'Ognjen Kuzmic',
  'Ömer Aşık':	  'Omer Asik',
  'Peja Stojaković':	  'Peja Stojakovic',
  'Pero Antić':	  'Pero Antic',
  'Perry Jones':	  'Perry Jones III',
  'Robert Williams':	  'Robert Williams III',
  'Roger Mason':	  'Roger Mason Jr.',
  'Rudy Fernández':	  'Rudy Fernandez',
  'Sasha Pavlović':	  'Sasha Pavlovic',
  'Sasha Vujačić':	  'Sasha Vujacic',
  'Sergio Rodríguez':	  'Sergio Rodriguez',
  'Skal Labissière':	  'Skal Labissiere',
  'Tibor Pleiß':	  'Tibor Pleiss',
  'Timothé Luwawu-Cabarrot':	  'Timothe Luwawu-Cabarrot',
  'Tomáš Satoranský':	  'Tomas Satoransky',
  'Vince Edwards':	  'Vincent Edwards',
  'Vince Hunter':	  'Vincent Hunter',
  'Vítor Luiz Faverani':	  'Vitor Faverani',
  'Vladimir Radmanović':	  'Vladimir Radmanovic',
  'Vlatko Čančar':	  'Vlatko Cancar',
  'Wade Baldwin':	  'Wade Baldwin IV',
  'Willy Hernangómez':	  'Willy Hernangomez',
  'Zach Norvell':	  'Zach Norvell Jr.',
  'Zoran Dragić':	  'Zoran Dragic'
}
def convert_name(name):
    if name in conversion_names:
        return conversion_names[name]
    else:
        return name
clean_stats['Player'] = clean_stats['Player'].apply(convert_name)
# Out:
# <ipython-input-53-bfd3038b2185>:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_stats['Player'] = clean_stats['Player'].apply(convert_name)

# %% [markdown]
# Reminder Danuel house Jr and danuel House are same and so is Marcus Morris Sr.

# %%
clean_stats

# %%
players_1 = set(clean_stats['Player'])
players_2 = set(df_filtered['player_name'])
players_3 = set(injuries_df.Player)
players_unique_1 = players_1 - players_2
players_unique_2 = players_2 - players_1
players_unique_3 = players_3 - players_2
#players_unique_4 = players_3 - players_1
(players_unique_1),(players_unique_2)#,(players_unique_3)#,(players_unique_4)
# Out:
# (set(), {'Danuel House', 'Marcus Morris'})

# %%
clean_stats.loc[clean_stats['Player']=='Marcus Morris']
# Out:
# Empty DataFrame
# Columns: [Player, Ht, Wt, Pos, Age, Tm, G, GS, MP, FGA, ORB, DRB, TRB, Year, Team]
# Index: []

# %%
df_filtered.loc[df_filtered['player_name'] == 'Danuel House', 'player_name'] = 'Danuel House Jr.'
df_filtered.loc[df_filtered['player_name'] == 'Marcus Morris', 'player_name'] = 'Marcus Morris Sr.'

# %% [markdown]
# Saving these two dataframes to be used later

# %%
df_filtered.to_csv('df_filtered.csv')
clean_stats.to_csv('clean_stats.csv')

# %% [markdown]
# ###Merge clean_stats and df_filtered wrt player_name, year and team.
# ### Remove duplicate names in injured_df ###

# %%
df_filtered.columns, clean_stats.columns

# %%
len(df_filtered), len(clean_stats)
# Out:
# (4934, 4934)

# %%
df_filtered.duplicated().sum(), clean_stats.duplicated().sum()
# Out:
# (0, 0)

# %%
merged_stats = pd.merge(df_filtered, clean_stats, left_on=['player_name', 'team_abbreviation','season'], right_on=['Player','Tm','Year'])
len(merged_stats), merged_stats.duplicated().sum()
# Out:
# (4874, 0)

# %% [markdown]
# While merging some data is being lost, need to figure out what's happening

# %% [markdown]
# Looks like the trades in between season are not counted

# %%
clean_stats.loc[clean_stats['Player']=='Svi Mykhailiuk']
# Out:
#                Player   Ht     Wt Pos  Age   Tm   G  GS    MP  FGA  ORB  DRB  \
# 15314  Svi Mykhailiuk  6-7  205.0  SF   21  DET  42   0  10.5  3.3  0.2  0.6
# 13938  Svi Mykhailiuk  6-7  205.0  SF   22  DET  56  27  22.6  7.2  0.3  1.6
#
#        TRB     Year             Team
# 15314  0.9  2018-19  Detroit Pistons
# 13938  1.9  2019-20  Detroit Pistons

# %%
df_filtered.loc[df_filtered['player_name']=='Svi Mykhailiuk']
# Out:
#           player_name team_abbreviation   age  player_height  player_weight  \
# 10393  Svi Mykhailiuk               DET  22.0         203.20       92.98636
# 10964  Svi Mykhailiuk               DET  23.0         200.66       92.98636
#
#         season
# 10393  2018-19
# 10964  2019-20

# %%
merged_stats.to_csv('merged_stats.csv')

# %%
players_1 = set(merged_stats['Player'])
players_3 = set(injuries_df.Player)
players_unique_1 = players_1 - players_3
players_unique_2 = players_3 - players_1

(players_unique_2)
# Out:
# {'Dylan Windler',
#  'Jared Harper',
#  'Kenny Wooten',
#  'Terrico White',
#  'Trevon Bluiett',
#  'Trevon Duval',
#  'Yakuba Ouattara'}

# %%
injuries_df.loc[injuries_df['Player']=='Yakuba Ouattara']
# Out:
#            Date Duplicates  PLAYER_ID           Player   Season     TEAM_ID  \
# 7422 2017-12-09          A    1628473  Yakuba Ouattara  2017-18  1610612751
#
#      TEAM_Abbr TEAM_CITY           Health problems           Organ systems  \
# 7422       BKN  Brooklyn  Musculoskeletal Injuries  Musculoskeletal system
#
#      Major anatomical areas Anatomical sub-areas Decision                Notes
# 7422        Lower extremity            Shin area      DTD  sore left leg (DTD)

# %%
#Missing Dylan Windler, Jared Harper, Kenny Wooten, Terrico White(never got to play), Trevon Bluiett, Trevon Duval, Yakuba Ouattara
merged_stats.loc[merged_stats['player_name']=='Tony Wroten']
# Out:
#       player_name team_abbreviation   age  player_height  player_weight  \
# 936   Tony Wroten               MEM  20.0         198.12      94.347136
# 1737  Tony Wroten               PHI  21.0         198.12      92.986360
# 2033  Tony Wroten               PHI  22.0         198.12      92.986360
#
#        season       Player   Ht     Wt Pos  ...   Tm   G  GS    MP   FGA  ORB  \
# 936   2012-13  Tony Wroten  6-6  205.0  SG  ...  MEM  35   0   7.8   2.5  0.4
# 1737  2013-14  Tony Wroten  6-6  205.0  PG  ...  PHI  72  16  24.5  11.2  1.0
# 2033  2014-15  Tony Wroten  6-6  205.0  PG  ...  PHI  30  15  29.8  14.5  0.7
#
#       DRB  TRB     Year                Team
# 936   0.4  0.8  2012-13   Memphis Grizzlies
# 1737  2.2  3.2  2013-14  Philadelphia 76ers
# 2033  2.1  2.9  2014-15  Philadelphia 76ers
#
# [3 rows x 21 columns]

# %% [markdown]
#  'C.J. McCollum':	'CJ McCollum',
#  'Danuel House':	Danuel House Jr.',
#  'Frank Mason III':	Frank Mason',
#  'Gerald Henderson Jr.':	'Gerald Henderson',
#  'Glen Rice Jr.':	  'Glen Rice',
#  "Hamady N'Diaye":	  'Hamady Ndiaye',
#  'Harry Giles':	  'Harry Giles III',
#  'James Ennis':	'James Ennis III',
#  'Jeff Taylor':	'Jeffery Taylor',
#  "Johnny O'Bryant":	  "Johnny O'Bryant III",
#  'Juan Hernangomez':	'Juancho Hernangomez',
#  'Kevin Knox':	  'Kevin Knox II':,
#  'Lonnie Walker':	'Lonnie Walker IV',
#  'Marcus Morris':	'Marcus Morris Sr.',
#  'Melvin Frazier':	  'Melvin Frazier Jr.',
#  'Michael Frazier':	  'Michael Frazier II',
#  'Nene Hilario':	  'Nene',
#  'Otto Porter':	'Otto Porter Jr.',
#  'Perry Jones':	  'Perry Jones III',
#  'Robert Williams':	  'Robert Williams III',
#  'Sviatoslav Mykhailiuk':	'Svi Mykhailiuk',
#  'Taurean Waller-Prince':	'Taurean Prince',
#  'Tony Wroten Jr.':	'Tony Wroten'

# %%
convert_injured={
 'C.J. McCollum':	'CJ McCollum',
 'Danuel House':	'Danuel House Jr.',
 'Frank Mason III':	'Frank Mason',
 'Gerald Henderson Jr.':	'Gerald Henderson',
 'Glen Rice Jr.':	  'Glen Rice',
 "Hamady N'Diaye":	  'Hamady Ndiaye',
 'Harry Giles':	  'Harry Giles III',
 'James Ennis':	'James Ennis III',
 'Jeff Taylor':	'Jeffery Taylor',
 "Johnny O'Bryant":	  "Johnny O'Bryant III",
 'Juan Hernangomez':	'Juancho Hernangomez',
 'Kevin Knox':	  'Kevin Knox II',
 'Lonnie Walker':	'Lonnie Walker IV',
 'Marcus Morris':	'Marcus Morris Sr.',
 'Melvin Frazier':	  'Melvin Frazier Jr.',
 'Michael Frazier':	  'Michael Frazier II',
 'Nene Hilario':	  'Nene',
 'Otto Porter':	'Otto Porter Jr.',
 'Perry Jones':	  'Perry Jones III',
 'Robert Williams':	  'Robert Williams III',
 'Sviatoslav Mykhailiuk':	'Svi Mykhailiuk',
 'Taurean Waller-Prince':	'Taurean Prince',
 'Tony Wroten Jr.':	'Tony Wroten'
 }

def convert_name(name):
    if name in convert_injured:
        return convert_injured[name]
    else:
        return name
injuries_df['Player'] = injuries_df['Player'].apply(convert_name)

# %%
injuries_df.to_csv('injuries_df.csv')

# %% [markdown]
# # **Some players have repeated injuries counted need to be sure what to do with that**

# %%
#https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6107769/ -> Another paper on NBA injuries
#https://link.springer.com/article/10.1007/s10796-020-10018-3#Sec3 -> Predicting Sports Injuries with Wearable Technology and Data Analysis
